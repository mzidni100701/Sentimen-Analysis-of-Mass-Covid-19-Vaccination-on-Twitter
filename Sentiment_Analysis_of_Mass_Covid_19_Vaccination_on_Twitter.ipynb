# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## 1. Import Package

# %%
import pandas as pd
import numpy as np
import tweepy
import matplotlib.pyplot as plt
import networkx as nx
from networkx.readwrite import json_graph
from plotly.offline import download_plotlyjs, init_notebook_mode,  iplot, plot
init_notebook_mode(connected=True)

# Machine Learning imports
import nltk
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
import joblib
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer

import string
import re
from string import punctuation
from collections import Counter
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2. GET & Explore Data

# %%
# Call twitter api keys
consumer_key = ' '
consumer_secret = ' '
access_token = ' '
access_secret = ' '
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="vaksin massal",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df = df.sort_values(['created_at'], ascending=[0])

# %%
df

# %%
df.to_csv("datatwittergabungan1.csv")

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="antre vaksin",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df1=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df1 = df1.sort_values(['created_at'], ascending=[0])
df1.to_csv("datatwittergabungan2.csv")
df1

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="kerumunan vaksin",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df2=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df2 = df2.sort_values(['created_at'], ascending=[0])
df2.to_csv("datatwittergabungan3.csv")
df2

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="vaksinasi massal",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df3=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df3 = df3.sort_values(['created_at'], ascending=[0])
df3.to_csv("datatwittergabungan4.csv")
df3

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="vaksinasi serentak",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df4=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df4 = df4.sort_values(['created_at'], ascending=[0])
df4.to_csv("datatwittergabungan5.csv")
df4

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="vaksin serentak",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df5=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df5 = df5.sort_values(['created_at'], ascending=[0])
df5.to_csv("datatwittergabungan6.csv")
df5

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="vaksin covid massal",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df6=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df6 = df6.sort_values(['created_at'], ascending=[0])
df6.to_csv("datatwittergabungan7.csv")
df6

# %%
# Search keywords
tweets = tweepy.Cursor(api.search,q="imunisasi covid massal",tweet_mode="extended",lang="id").items(750)
message,retweet_count,retweet,created_at,user_name,user_id=[],[],[],[],[],[]
count = 0
for tweet in tweets:
    count=count+1
    if hasattr(tweet, 'retweeted_status'):
        message.append(tweet.retweeted_status.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(tweet.retweeted_status.user.screen_name)
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
    else:
        message.append(tweet.full_text)
        retweet_count.append(tweet.retweet_count)
        retweet.append(print(''))
        created_at.append(tweet.created_at)
        user_name.append(tweet.user.screen_name)
        user_id.append(tweet.user.id)
# insert tweets to database
for i in range(count):
    data=[message[i], retweet_count[i], retweet[i], created_at[i], user_name[i], user_id[i]]

# %%
# make dataframe
df7=pd.DataFrame({
    'author':retweet,
    'username':user_name,
    'retweet_count':retweet_count,
    'tweets':message,
    'created_at':created_at
})
df7 = df7.sort_values(['created_at'], ascending=[0])
df7.to_csv("datatwittergabungan8.csv")
df7

# %%
frames = [df1, df2, df3, df4, df5, df6, df7] 
datatwittergabungan = df.append(frames, ignore_index = True)

# %%
datatwittergabungan

# %%
datatwittergabungan.to_csv("datatwittergabungan.csv")

# %% [markdown]
# ## 2. Drop Duplicate Data

# %%
# drop duplicates
data = datatwittergabungan.drop_duplicates('tweets')
data.shape

# %%
data

# %%
data.to_csv("datatwittergabungan.csv")

# %% [markdown]
# ## 3. Preprocessing Data

# %%
df = pd.read_csv('final labeling.csv')

# %%
df
# Out:
#       Column1         author       username  ...  labeling 2 labeling 3 Hasil
# 0           0    dodon_jerry         unytok  ...           1          1     1
# 1           1       KamituoN   indahjegeg14  ...           1          1     1
# 2           2  aurora_langit   indahjegeg14  ...           1          1     1
# 3           3   namakucingka   indahjegeg14  ...           1          1     1
# 4           4    JatengOpini      S4fitr1HS  ...           1          1     1
# ...       ...            ...            ...  ...         ...        ...   ...
# 1416     5340            NaN     kimcipedes  ...           1          1     1
# 1417     5341            NaN        dievaaa  ...           0          0     0
# 1418     5342       Susierna       susindra  ...           1          1     1
# 1419     5346            NaN        jpnncom  ...           1          1     1
# 1420     5347            NaN  KallaGroup_ID  ...           1          1     1
#
# [1421 rows x 10 columns]

# %%
# helper function to clean tweets
def processTweet(tweet):
    # Remove HTML special entities (e.g. &amp;)
    tweet = re.sub(r'\&\w*;', '', tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    # Remove tickers
    tweet = re.sub(r'\$\w*', '', tweet)
    # To lowercase
    tweet = tweet.lower()
    # Remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*\/\w*', '', tweet)
    # Remove hashtags
    tweet = re.sub(r'#\w*', '', tweet)
    # Remove Punctuation and split 's, 't, 've with a space for filter
    tweet = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', tweet)
    # Remove words with 2 or fewer letters
    tweet = re.sub(r'\b\w{1,2}\b', '', tweet)
    # Remove whitespace (including new line characters)
    tweet = re.sub(r'\s\s+', ' ', tweet)
    # Remove single space remaining at the front of the tweet.
    tweet = tweet.lstrip(' ') 
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 

    
    return tweet

# %%
# # Delete KeyWords
# def processTweet2(tweet):
#     # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksinasi', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksin massal', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksin', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'massal', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'antre vaksin', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'antre', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'kerumunan vaksin', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'kerumunan', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksinasi massal', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksinasi serentak', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'serentak', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksin serentak', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'vaksin covid massal', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'covid', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'massal', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'imunisasi covid massal', ' ', tweet)
#   # Remove whitespace (including new line characters)
#     tweet = re.sub(r'imunisasi', ' ', tweet)
#     return tweet

# %%
# clean dataframe's text column
df['tweets'] = df['tweets'].apply(processTweet)
# clean dataframe's text column
# df['tweets'] = df['tweets'].apply(processTweet2)
# preview some cleaned tweets
df['tweets'].head()
# Out:
# 0    seneng banget sekarang akhirnya ngga cuman ora...
# 1    kita selalu berharap vaksinasi dilakukan cepat...
# 2    alhamdulillah pemerintah gerak cepat dengan me...
# 3    kita selalu berharap vaksinasi dilakukan cepat...
# 4    akbar izza davi dan saka adalah siswa kota sem...
# Name: tweets, dtype: object

# %%
# drop duplicates
df = df.drop_duplicates('tweets')
df.shape
# Out:
# (1320, 10)

# %%
pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
#stopwords baruu
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
list_stop_words = StopWordRemoverFactory().get_stop_words()
stemming = StemmerFactory().create_stemmer()
# tokenize helper function
def text_process(raw_text):
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in list_stop_words]

# -------------------------------------------

# tokenize message column and create a column for tokens
df = df.copy()
df['tokens'] = df['tweets'].apply(text_process) # tokenize style 1
df[['tweets','tokens']].head(20)
# Out:
#                                                tweets                                             tokens
# 0   seneng banget sekarang akhirnya ngga cuman ora...  [seneng, banget, sekarang, akhirnya, ngga, cum...
# 1   kita selalu berharap vaksinasi dilakukan cepat...  [selalu, berharap, vaksinasi, dilakukan, cepat...
# 2   alhamdulillah pemerintah gerak cepat dengan me...  [alhamdulillah, pemerintah, gerak, cepat, meng...
# 4   akbar izza davi dan saka adalah siswa kota sem...  [akbar, izza, davi, saka, siswa, kota, semaran...
# 5   kita selalu berharap vaksinasi dilakukan cepat...  [selalu, berharap, vaksinasi, dilakukan, cepat...
# 7   ratusan warga trenggalek ikuti vaksinasi massa...  [ratusan, warga, trenggalek, ikuti, vaksinasi,...
# 8   guys kita selalu berharap vaksinasi dilakukan ...  [guys, selalu, berharap, vaksinasi, dilakukan,...
# 10  min vaksin massal gratis gerai vaksin presisi ...  [min, vaksin, massal, gratis, gerai, vaksin, p...
# 11  dalam rangka membantu pemerintah mencegah penu...  [rangka, membantu, pemerintah, mencegah, penul...
# 12  bbrp kali lihat video vaksinisasi massal berke...  [bbrp, kali, lihat, video, vaksinisasi, massal...
# 13  antrian vaksin massal kupang pagi ini hmmmm pa...  [antrian, vaksin, massal, kupang, pagi, hmmmm,...
# 14  bangga melihat anak2 pelajar bersemangat utk v...  [bangga, melihat, anak2, pelajar, bersemangat,...
# 15  guys kita selalu berharap vaksinasi dilakukan ...  [guys, selalu, berharap, vaksinasi, dilakukan,...
# 16  ngecek stasiun sumpa sub mayan sih ada vaksin ...  [ngecek, stasiun, sumpa, sub, mayan, sih, vaks...
# 17  antusias para siswa terlihat smp semarang pagi...  [antusias, siswa, terlihat, smp, semarang, pag...
# 18  ganjar tanggapi tudingan vaksin pembunuh massa...  [ganjar, tanggapi, tudingan, vaksin, pembunuh,...
# 19  aneh nya dah banyak makan korban eeeeeee malah...  [aneh, nya, dah, banyak, makan, korban, eeeeee...
# 20  serbuan vaksin covid anak umur tahun kodim 130...  [serbuan, vaksin, covid, anak, umur, tahun, ko...
# 21  bukan soal percaya pemrinah atau enggak tpi lo...  [bukan, soal, percaya, pemrinah, enggak, tpi, ...
# 22  bin menggelar vaksinasi massal untuk pelajar y...  [bin, menggelar, vaksinasi, massal, pelajar, d...

# %% [markdown]
# ## 4. Word Cloud

# %%
df1=df.copy()
df1= df[df['Hasil']==1]
df1
# Out:
#       Column1  ...                                             tokens
# 0           0  ...  [seneng, banget, sekarang, akhirnya, ngga, cum...
# 1           1  ...  [selalu, berharap, vaksinasi, dilakukan, cepat...
# 2           2  ...  [alhamdulillah, pemerintah, gerak, cepat, meng...
# 4           4  ...  [akbar, izza, davi, saka, siswa, kota, semaran...
# 5           5  ...  [selalu, berharap, vaksinasi, dilakukan, cepat...
# ...       ...  ...                                                ...
# 1415     5339  ...  [hari, rabu, tanggal, juli, 2021, jam, wib, be...
# 1416     5340  ...  [mabes, tni, pantau, penyelenggaraan, suntik, ...
# 1418     5342  ...  [pembatasan, kegiatan, masyarakat, menjadi, sa...
# 1419     5346  ...  [vaksin, covid, massal, gelora, nopember, seha...
# 1420     5347  ...  [terima, kasih, ucapkan, tim, satgas, covid, k...
#
# [1023 rows x 11 columns]

# %%
df0=df.copy()
df0= df[df['Hasil']==0]
df0
# Out:
#       Column1  ...                                             tokens
# 12         16  ...  [bbrp, kali, lihat, video, vaksinisasi, massal...
# 13         17  ...  [antrian, vaksin, massal, kupang, pagi, hmmmm,...
# 16         26  ...  [ngecek, stasiun, sumpa, sub, mayan, sih, vaks...
# 18         29  ...  [ganjar, tanggapi, tudingan, vaksin, pembunuh,...
# 19         30  ...  [aneh, nya, dah, banyak, makan, korban, eeeeee...
# ...       ...  ...                                                ...
# 1370     5236  ...  [katanya, hindari, kerumunan, kalo, namanya, a...
# 1378     5252  ...  [disuruh, wajib, vaksin, karna, terpaksa, kebi...
# 1381     5261  ...  [ngga, cluster, covid, vaksin, massal, ramenya...
# 1406     5312  ...  [vaksin, massal, apa, mau, arisan, covid, jancuk]
# 1417     5341  ...  [bener2, covidiot, banyak, banget, jadi, kemar...
#
# [297 rows x 11 columns]

# %% [markdown]
# ### WC Total

# %%
all_words = []
for line in df['tokens']: 
    all_words.extend(line)  
# create a word frequency dictionary
wordfreq = Counter(all_words)
wordfreq.most_common(10)
# Out:
# [('vaksin', 1257),
#  ('vaksinasi', 787),
#  ('massal', 717),
#  ('covid', 304),
#  ('kerumunan', 291),
#  ('serentak', 252),
#  ('antre', 190),
#  ('orang', 175),
#  ('kota', 156),
#  ('mau', 140)]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='gist_rainbow',
                      normalize_plurals=True).generate_from_frequencies(wordfreq)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### WC Positif

# %%
all_words = []
for line in df1['tokens']: 
    all_words.extend(line)  
# create a word frequency dictionary
wordfreq1 = Counter(all_words)
wordfreq1.most_common(10)
# Out:
# [('vaksin', 866),
#  ('vaksinasi', 729),
#  ('massal', 614),
#  ('covid', 241),
#  ('serentak', 239),
#  ('kota', 148),
#  ('antre', 125),
#  ('orang', 124),
#  ('masyarakat', 124),
#  ('kerumunan', 123)]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='gist_rainbow',
                      normalize_plurals=True).generate_from_frequencies(wordfreq1)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### WC Negatif

# %%
all_words = []
for line in df0['tokens']: 
    all_words.extend(line)  
# create a word frequency dictionary
wordfreq0 = Counter(all_words)
wordfreq0.most_common(10)
# Out:
# [('vaksin', 391),
#  ('kerumunan', 168),
#  ('massal', 103),
#  ('antre', 65),
#  ('covid', 63),
#  ('vaksinasi', 58),
#  ('mau', 53),
#  ('orang', 51),
#  ('gak', 49),
#  ('banyak', 41)]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='gist_rainbow',
                      normalize_plurals=True).generate_from_frequencies(wordfreq0)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## 5. Feature Extraction

# %%
# vectorize
bow_transformer = CountVectorizer(analyzer=text_process).fit(df['tweets'])
# print total number of vocab words
print(len(bow_transformer.vocabulary_))
# example of vectorized text
sample_tweet = df['tweets'][0]
print(sample_tweet)
print('\n')
# vector representation
bow_sample = bow_transformer.transform([sample_tweet])
print(bow_sample)
print('\n')
# Out:
# 5256
# seneng banget sekarang akhirnya ngga cuman orang tua diatas tahun dan masyarakat diatas tahun yang mendapat vaksinasi program vaksinasi massal menyerbu sekolah untuk umur tahun juga hayoo siapa yang belum vaksin yuk segera cari informasi
#
#
#   (0, 134)	1
#   (0, 365)	1
#   (0, 801)	1
#   (0, 884)	1
#   (0, 999)	2
#   (0, 1695)	1
#   (0, 1821)	1
#   (0, 2727)	1
#   (0, 2732)	1
#   (0, 2886)	1
#   (0, 3038)	1
#   (0, 3318)	1
#   (0, 3441)	1
#   (0, 3932)	1
#   (0, 4251)	1
#   (0, 4281)	1
#   (0, 4289)	1
#   (0, 4339)	1
#   (0, 4414)	1
#   (0, 4641)	3
#   (0, 4950)	1
#   (0, 5012)	1
#   (0, 5065)	1
#   (0, 5067)	2
#   (0, 5209)	1

# %%
# transform the entire DataFrame of messages
messages_bow = bow_transformer.transform(df['tweets'])

# check out the bag-of-words counts for the entire corpus as a large sparse matrix
print('Shape of Sparse Matrix: ', messages_bow.shape)
print('Amount of Non-Zero occurences: ', messages_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (1320, 5256)
# Amount of Non-Zero occurences:  22784

# %%
tfidf_transformer = TfidfTransformer().fit(messages_bow)
tfidf_sample = tfidf_transformer.transform(bow_sample)
print(tfidf_sample)
# Out:
#   (0, 5209)	0.16891064755439997
#   (0, 5067)	0.11196388719492094
#   (0, 5065)	0.04402261108530552
#   (0, 5012)	0.19298916029806457
#   (0, 4950)	0.1441258189904792
#   (0, 4641)	0.3955669965601886
#   (0, 4414)	0.19678464432258705
#   (0, 4339)	0.21912087496732247
#   (0, 4289)	0.14573737324608976
#   (0, 4281)	0.15419189616479828
#   (0, 4251)	0.14112603883016933
#   (0, 3932)	0.11914986074890402
#   (0, 3441)	0.10276132305964104
#   (0, 3318)	0.17444841367785163
#   (0, 3038)	0.24145710561205788
#   (0, 2886)	0.21193021478889806
#   (0, 2732)	0.10669317787246553
#   (0, 2727)	0.053813124904644155
#   (0, 1821)	0.21193021478889806
#   (0, 1695)	0.24145710561205788
#   (0, 999)	0.43824174993464493
#   (0, 884)	0.20108760921608143
#   (0, 801)	0.16568552123671706
#   (0, 365)	0.14573737324608976
#   (0, 134)	0.1837187869879581

# %%
# # some IDF (inverse document frequency) example
# print(tfidf_transformer.idf_[bow_transformer.vocabulary_['vaksin']])
# print(tfidf_transformer.idf_[bow_transformer.vocabulary_['massal']])

# %%
# to transform the entire bag-of-words corpus
messages_tfidf = tfidf_transformer.transform(messages_bow)
print(messages_tfidf.shape)
# Out:
# (1320, 5256)

# %% [markdown]
# ## 6. Training

# %%
data=df.copy()
data.head()
# Out:
#    Column1  ...                                             tokens
# 0        0  ...  [seneng, banget, sekarang, akhirnya, ngga, cum...
# 1        1  ...  [selalu, berharap, vaksinasi, dilakukan, cepat...
# 2        2  ...  [alhamdulillah, pemerintah, gerak, cepat, meng...
# 4        4  ...  [akbar, izza, davi, saka, siswa, kota, semaran...
# 5        5  ...  [selalu, berharap, vaksinasi, dilakukan, cepat...
#
# [5 rows x 11 columns]

# %% [markdown]
# ##Naive Bayes

# %%
X_train, X_test, y_train, y_test = train_test_split(data['tweets'], data['Hasil'], test_size=0.2, random_state=123)


# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'classifier__alpha': (1e-2, 1e-3),
             }

# do 10-fold cross validation for each of the 6 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=10, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# save best model to current working directory
joblib.dump(grid, "twitter_sentiment.pkl")
# load from file and predict using the best configs found in the CV step
model_NB = joblib.load("twitter_sentiment.pkl" )

# get predictions from best model above
y_preds = model_NB.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:    5.9s finished
# Best Model: 0.824753 using {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
#
#
# Mean: 0.810548 Stdev:(0.038574) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.806757 Stdev:(0.037961) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.810602 Stdev:(0.030233) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.811545 Stdev:(0.031575) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
# Mean: 0.820000 Stdev:(0.041435) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.819039 Stdev:(0.050215) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.823801 Stdev:(0.032957) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.824753 Stdev:(0.031840) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
# accuracy score:  0.8181818181818182
#
#
# confusion matrix:
#  [[ 36  27]
#  [ 21 180]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.57      0.60        63
#            1       0.87      0.90      0.88       201
#
#     accuracy                           0.82       264
#    macro avg       0.75      0.73      0.74       264
# weighted avg       0.81      0.82      0.81       264

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(data['tweets'], data['Hasil'], test_size=0.2, random_state=123)


# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', RandomForestClassifier()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'classifier__criterion' :['gini', 'entropy']
             }

# do 10-fold cross validation for each of the 6 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=10, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# save best model to current working directory
joblib.dump(grid, "twitter_sentiment3.pkl")
# load from file and predict using the best configs found in the CV step
model_RFC = joblib.load("twitter_sentiment3.pkl" )

# get predictions from best model above
y_preds = model_RFC.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:   43.4s finished
# Best Model: 0.828544 using {'bow__ngram_range': (1, 2), 'classifier__criterion': 'gini', 'tfidf__use_idf': True}
#
#
# Mean: 0.825723 Stdev:(0.023536) with: {'bow__ngram_range': (1, 1), 'classifier__criterion': 'gini', 'tfidf__use_idf': True}
# Mean: 0.820027 Stdev:(0.018481) with: {'bow__ngram_range': (1, 1), 'classifier__criterion': 'gini', 'tfidf__use_idf': False}
# Mean: 0.821905 Stdev:(0.024331) with: {'bow__ngram_range': (1, 1), 'classifier__criterion': 'entropy', 'tfidf__use_idf': True}
# Mean: 0.824753 Stdev:(0.019099) with: {'bow__ngram_range': (1, 1), 'classifier__criterion': 'entropy', 'tfidf__use_idf': False}
# Mean: 0.828544 Stdev:(0.028603) with: {'bow__ngram_range': (1, 2), 'classifier__criterion': 'gini', 'tfidf__use_idf': True}
# Mean: 0.812462 Stdev:(0.022282) with: {'bow__ngram_range': (1, 2), 'classifier__criterion': 'gini', 'tfidf__use_idf': False}
# Mean: 0.827610 Stdev:(0.034090) with: {'bow__ngram_range': (1, 2), 'classifier__criterion': 'entropy', 'tfidf__use_idf': True}
# Mean: 0.825696 Stdev:(0.027298) with: {'bow__ngram_range': (1, 2), 'classifier__criterion': 'entropy', 'tfidf__use_idf': False}
# accuracy score:  0.8371212121212122
#
#
# confusion matrix:
#  [[ 29  34]
#  [  9 192]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.46      0.57        63
#            1       0.85      0.96      0.90       201
#
#     accuracy                           0.84       264
#    macro avg       0.81      0.71      0.74       264
# weighted avg       0.83      0.84      0.82       264

# %% [markdown]
# ##SVM

# %%
from sklearn.svm import SVC
X_train, X_test, y_train, y_test = train_test_split(data['tweets'], data['Hasil'], test_size=0.2, random_state=123)


# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', SVC(kernel='linear')),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
             }

# do 10-fold cross validation for each of the 6 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=10, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# save best model to current working directory
joblib.dump(grid, "twitter_sentiment2.pkl")
# load from file and predict using the best configs found in the CV step
model_SVM = joblib.load("twitter_sentiment2.pkl" )

# get predictions from best model above
y_preds = model_SVM.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   10.2s finished
# Best Model: 0.838940 using {'bow__ngram_range': (1, 2), 'tfidf__use_idf': False}
#
#
# Mean: 0.834241 Stdev:(0.032311) with: {'bow__ngram_range': (1, 1), 'tfidf__use_idf': True}
# Mean: 0.836110 Stdev:(0.028767) with: {'bow__ngram_range': (1, 1), 'tfidf__use_idf': False}
# Mean: 0.838931 Stdev:(0.034316) with: {'bow__ngram_range': (1, 2), 'tfidf__use_idf': True}
# Mean: 0.838940 Stdev:(0.033652) with: {'bow__ngram_range': (1, 2), 'tfidf__use_idf': False}
# accuracy score:  0.8446969696969697
#
#
# confusion matrix:
#  [[ 38  25]
#  [ 16 185]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.60      0.65        63
#            1       0.88      0.92      0.90       201
#
#     accuracy                           0.84       264
#    macro avg       0.79      0.76      0.77       264
# weighted avg       0.84      0.84      0.84       264

# %% [markdown]
# ## 7. Predict

# %%
print(y_train)
print(X_train)
# Out:
# 1143    1
# 651     1
# 276     1
# 92      1
# 1063    1
#        ..
# 1331    1
# 1239    1
# 124     1
# 1125    1
# 1211    1
# Name: Hasil, Length: 1056, dtype: int64
# 1143    kenapa vaksinasi tidak dilakukan secara serent...
# 651     semangat terus saat nya kita menunggu dirumah ...
# 276     gemes bgt btw baiknya utk org kaya gitu penjel...
# 92                 klo tempat ada vaksin massal boleh tuh
# 1063    president via virtual pantau langsung vaksinas...
#                               ...
# 1331    tinjau vaksinasi massal surabaya puan berikan ...
# 1239    hari ini pemerintah menggelar vaksin serentak ...
# 124     laksanakan vaksinasi massal forkompinda kepri ...
# 1125    presiden joko widodo jokowi meninjau pelaksana...
# 1211    panglima tni menyampaikan bahwa indonesia seda...
# Name: tweets, Length: 1056, dtype: object

# %%
y_preds1 = model_SVM.predict(X_train)

# %%
y_preds1
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# run predictions on twitter data
tweet_preds = model_SVM.predict(df['tweets'])

# append predictions to dataframe
df_tweet_preds = df.copy()
df_tweet_preds['predictions'] = tweet_preds
df_tweet_preds.shape
# Out:
# (1320, 12)

# %%
df_tweet_preds
# Out:
#       Column1  ... predictions
# 0           0  ...           1
# 1           1  ...           1
# 2           2  ...           1
# 4           4  ...           1
# 5           5  ...           1
# ...       ...  ...         ...
# 1416     5340  ...           1
# 1417     5341  ...           0
# 1418     5342  ...           1
# 1419     5346  ...           1
# 1420     5347  ...           1
#
# [1320 rows x 12 columns]

# %%
pos = df_tweet_preds.predictions.value_counts()[0]
neg = df_tweet_preds.predictions.value_counts()[1]

print('Model predictions: Positives - {}, Negatives - {}'.format(neg,pos))
# Out:
# Model predictions: Positives - 1045, Negatives - 275

# %%
import plotly.graph_objs as go

labels = ['Positif','Negatif']
values = [int(pos),int(neg)]

trace = go.Pie(labels=labels, values=values)
iplot([trace], filename='basic_pie_chart')
# Out:
# <div>
#
#
#             <div id="174ed4ec-8283-4fab-8aaa-39ea40b3ce22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("174ed4ec-8283-4fab-8aaa-39ea40b3ce22")) {
#                     Plotly.newPlot(
#                         '174ed4ec-8283-4fab-8aaa-39ea40b3ce22',
#                         [{"labels": ["Positif", "Negatif"], "type": "pie", "values": [275, 1045]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ## 8. Social Network Analysis

# %%
# Remove null account
df=df.dropna()
len(df)

# %%
# Netwrokx
net = nx.from_pandas_edgelist(df, source="author", target="username")
# Plot it
nx.draw(net, with_labels=False, node_size=25)
plt.show()

# %%
G = nx.convert_node_labels_to_integers(net, first_label=0, ordering='default', label_attribute=None)
pos=nx.fruchterman_reingold_layout(G)
#create labels
poslabs=nx.fruchterman_reingold_layout(net)
labels=list(poslabs) + list(' : ')
#create edges
Xe=[]
Ye=[]
for e in G.edges():
    Xe.extend([pos[e[0]][0], pos[e[1]][0], None])
    Ye.extend([pos[e[0]][1], pos[e[1]][1], None])
trace_edges=dict(type='scatter',
                 mode='lines',
                 x=Xe,
                 y=Ye,
                 line=dict(width=1, color='rgb(25,25,25)'),
                 hoverinfo='none' 
                )

#create nodes
Xn=[pos[k][0] for k in range(len(pos))]
Yn=[pos[k][1] for k in range(len(pos))]
trace_nodes=dict(type='scatter',
                 x=Xn, 
                 y=Yn,
                 mode='markers',
                 marker=dict(showscale=True,size=5,color=[],colorscale='Rainbow',reversescale=True,colorbar=dict(
                    thickness=15,
                    title='Node Connections',
                    xanchor='left',
                    titleside='right')),
                 text=labels,
                 hoverinfo='text')

#scale color by size
for node, adjacencies in enumerate(G.adjacency()):
    trace_nodes['marker']['color']+=tuple([len(adjacencies[1])])
#plot
axis=dict(showline=False, # hide axis line, grid, ticklabels and  title
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title='' 
          )
layout=dict(title= 'Social Network Analysis',  
            font= dict(family='Balto'),
            width=1000,
            height=1000,
            autosize=False,
            showlegend=False,
            xaxis=axis,
            yaxis=axis,
            margin=dict(l=40,r=40,b=85,t=100,pad=0,
            ),
            hovermode='closest',
#     plot_bgcolor='#000000',           
    )
fig = dict(data=[trace_edges,trace_nodes], layout=layout)
#run plot
iplot(fig)
plot(fig, filename='myplot.html')
